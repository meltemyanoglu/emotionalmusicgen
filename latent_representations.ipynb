# %%
config = {
    "processed_data_dir": "processed_data",
    "output_dir": "latent_representations",
    "chunk_sizes": [5, 10],  # Segment lengths to be processed
    "encodec_bandwidth": 6.0,  # In kbps
    "max_samples": None,  # None = all data
    "test_reconstruction": False  # Should reconstruction testing be performed?
}

# %% [markdown]
# # Import Required Libraries

# %%
import utils._latentspace
from utils._latentspace import *

# %matplotlib inline
plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# # Model and Dataloader Setup

# %% [markdown]
# ## Load Encodec Model

# %%
latent_gen = LatentRepresentationGenerator(
    processed_data_dir=config["processed_data_dir"],
    output_dir=config["output_dir"],
    encodec_bandwidth=config["encodec_bandwidth"],
    chunk_sizes=config["chunk_sizes"]
)
# Out:
# Kullanılan cihaz: cpu
# EnCodec modeli yükleniyor...
# c:\Users\byemi\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\utils\weight_norm.py:30: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# EnCodec modeli başarıyla yüklendi (hedef bant genişliği: 6.0 kbps)

# %% [markdown]
# # Generating Latent Representations

# %% [markdown]
# ## Run the process for all segment lengths

# %%
results = latent_gen.run(max_samples=config["max_samples"])
# Out:
# 5s segmentleri işleniyor...
# Toplam 15687 segment bulundu (5s)
# 5s segmentler encode ediliyor:   0%|          | 0/491 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 results = latent_gen.run(max_samples=config["max_samples"])
#
# Input In [9], in LatentRepresentationGenerator.run(self, max_samples)
#     285 results = {}
#     287 for chunk_size in self.chunk_sizes:
# --> 288     latents, metadata = self.process_segments(
#     289         chunk_size=chunk_size,
#     290         max_samples=max_samples
#     291     )
#     292     results[chunk_size] = (latents, metadata)
#     294 print("\n--- Latent Temsil Oluşturma İşlemi Tamamlandı ---")
#
# Input In [9], in LatentRepresentationGenerator.process_segments(self, chunk_size, batch_size, max_samples)
#      84 waveforms_batch = torch.stack(waveforms_24k)
# ...

# %% [markdown]
# # Visualizing the Results

# %% [markdown]
# ## Example Latent Space Visualization

# %%
def show_latent_visualization(chunk_size=10):
    img_path = os.path.join(config["output_dir"], f'latent_tsne_{chunk_size}s_separate.png')
    plt.figure(figsize=(20,10))
    plt.imshow(plt.imread(img_path))
    plt.axis('off')
    plt.show()

show_latent_visualization()
